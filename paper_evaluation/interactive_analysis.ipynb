# %% [markdown]
# # Interactive Analysis Notebook
#
# This notebook provides interactive analysis of benchmark results with real-time plotting and statistical analysis.
#
# ## Table of Contents
# 1. [Setup and Data Loading](#setup)
# 2. [Statistical Analysis](#statistics)
# 3. [Interactive Plotting](#plotting)
# 4. [Custom Metric Exploration](#exploration)
# 5. [Export Publication Figures](#export)
# 6. [LaTeX Table Generation](#latex)
